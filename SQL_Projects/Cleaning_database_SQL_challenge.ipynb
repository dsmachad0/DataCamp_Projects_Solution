# %% [markdown]
# ## 1. Online News Exhibition
# <p>Following the changes in working habits during the COVID pandemic, your local library has decided it is time to make the newspaper archives available online. They are not sure what the response will be so they are going to trial a new system on a small set of their data. </p>
# <p>The library database has a table <code>articles</code> with a record of all articles published in the newspaper. However, the table will need some preparation before the library can use it in the new system. They would like to focus the initial trial on articles from 2014 and 2015 only, and for just one journalist whose ID in the database is 1754.</p>
# <p>The final results should be sorted from earliest published date to the most recent published date.</p>
# <p>Below are the requirements the library has given to you for the data they need. </p>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">Requirements</th>
# <th style="text-align:left;">Data Type</th>
# <th style="text-align:left;">Column Alias</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;">Unique ID of each article, where the first 4 digits represents the journalist ID.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">article_key</td>
# </tr>
# <tr>
# <td style="text-align:left;">Category of the article, in uppercase.  'Food &amp; Drink' and 'Wellness' should be collapsed  into a 'Lifestyle' category.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">category</td>
# </tr>
# <tr>
# <td style="text-align:left;">Headline of the article, without the subtitle that appears after the colon (:).  For example, 'It Could Happen To You: A Story of SEC Overreach' becomes 'It Could Happen To You'.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">headline</td>
# </tr>
# <tr>
# <td style="text-align:left;">Subtitles of the article, without the headline that appears before the colon (:). For example, 'It Could Happen to You: A Story of SEC Overreach' becomes 'A Story of SEC Overreach'. In cases where a headline does not have a subtitle, the missing value should read ‘None’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">subtitle</td>
# </tr>
# <tr>
# <td style="text-align:left;">Description of the article. The description should be reduced to the first sentence, up to and including the first period (.) from the short_description column.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">description</td>
# </tr>
# <tr>
# <td style="text-align:left;">Keywords of the article. Multiple keywords will be seperated with a dash (-). If the keyword is missing, the value should read ‘Unknown’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">keywords</td>
# </tr>
# <tr>
# <td style="text-align:left;">Date the article was published. The data should be displayed in the format resembling the following: ‘Aug 13, 1995’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">publish_date</td>
# </tr>
# </tbody>
# </table>

# %%
# %%sql
# postgresql:///articles
#
# SELECT *
# FROM articles
# LIMIT 100
# Out:
# 100 rows affected.
# [('1758', 'Lifestyle', 'Recipe Of The Day', "It's one root vegetable you want to know.", '2013-03-01', 'jicama-recipes-salad', ' Jicama Salad'),
#  ('1757', 'World News', 'Turkey Removes Two Dozen Elected Mayors In Kurdish Areas', 'Police fired water cannons at protesters over the removals.', '2016-09-11', 'turkey-kurds-crackdown', 'None'),
#  ('1754', 'Parenting', '9 Holiday Survival Strategies For Moms', '3.', '2012-12-25', 'christmas-survival-strategies', 'None'),
#  ('1756', 'Lifestyle', 'Happiness Tips', 'We asked authors and thinkers for their best piece of advice on the pursuit of joy.', '2013-02-28', 'happiness-tips-pursuit-of-happiness', ' 13 Experts Weigh In On The Pursuit Of Joy'),
#  ('1754', 'Business', 'The War On Meetings', 'They’re boring.', '2016-02-25', 'Unknown', 'None'),
#  ('1754', 'Lifestyle', 'Stylish Yellow Kitchen Accessories And Appliances', 'While spring might not be here quite yet -- the taste of young asparagus and English peas is still slightly out of reach.', '2012-02-28', 'yellow-kitchen-items', 'None'),
#  ('1757', 'Lifestyle', 'Wild Meditation', 'Meditate for years.', '2014-03-12', 'wild-meditation', 'None'),
#  ('1754', 'Parenting', '11 Totally Normal Things That Happen During Pregnant Sex ... And After', '4.', '2013-10-25', 'pregnant-sex', 'None'),
#  ('1755', 'Parenting', 'Why French Kids Eat Everything', "So what's the secret.", '2012-07-13', 'french-food', 'None'),
#  ('1756', 'Lifestyle', 'These Oatmeal Recipes Are Worth Waking Up For', "These aren't the wretched porridges of your childhood.", '2012-10-10', 'oatmeal-recipes', 'None'),
#  ('1756', 'Parenting', 'Which Parent Are You? Do As I Say vs. Do As I Do', "I'm a flip-flopper.", '2012-07-18', 'parenting-advice', 'None'),
#  ('1757', 'Lifestyle', 'Thousands Of Doctors Practicing Despite Errors, Misconduct', 'Dr.', '2013-08-21', 'Unknown', 'None'),
#  ('1757', 'Lifestyle', '8 Desserts You Can Make In Mason Jars (PHOTO)', "Glass jars aren't just for jam anymore.", '2013-11-06', 'Unknown', 'None'),
#  ('1756', 'Business', 'To Court, or Not to Court', 'Avoid litigation when you can.', '2014-06-17', 'to-court-or-not-to-court-litigation', 'None'),
#  ('1756', 'Business', "This Could Be Donald Trump's Biggest Lie", 'How rich is he.', '2016-05-21', 'donald-trumps-biggest-lie', 'None'),
#  ('1757', 'Politics', 'Texas To Consider Bathroom Restrictions For Trans People This Summer', 'Gov.', '2017-06-06', 'texas-trans-bathroom-restrictions', 'None'),
#  ('1756', 'Lifestyle', '10 Recipes for a Cinco de Mayo Fiesta', 'Here are some of our favorite Mexican-inspired dishes to help you effortlessly plan your best fiesta yet.', '2013-04-25', '10-recipes-for-a-cinco-de', 'None'),
#  ('1757', 'Lifestyle', '11 Things That Are Better When Not Perfect', 'We love an ideal moment: a lemonade-pink sunset savored from a seaside balcony.', '2012-09-26', 'Unknown', 'None'),
#  ('1754', 'Parenting', 'Babies Try To Stay Awake -- And Fail Adorably [VIDEO]', 'We get it.', '2012-12-13', 'babies-falling-asleep-video', 'None'),
#  ('1758', 'Parenting', 'Breaking the Webs of My Weaving', 'May tide and weather wait for your coming.', '2013-04-12', 'breaking-the-webs-of-my-w', 'None'),
#  ('1758', 'Parenting', '10 More Types of Moms on Facebook', 'Hey, Facebook Moms.', '2012-11-09', '10-more-types-of-moms-on', 'None'),
#  ('1758', 'Parenting', "I'm Sorry", 'Look mom.', '2012-08-13', 'im-sorry', 'None'),
#  ('1755', 'World News', 'Benjamin Netanyahu', 'Kerry “obsessively dealt with settlements.', '2016-12-28', 'netanyahu-john-kerry-speech', " John Kerry's Speech Biased Against Israel"),
#  ('1757', 'Lifestyle', "Cookies Are Crazy. It's Science. (VIDEO)", "It's science.", '2013-12-03', 'cookies', 'None'),
#  ('1755', 'Parenting', "Children's Mental Health", 'Dr.', '2012-05-10', 'childrens-mental-health-quiz', ' Can You Recognize Myths About Autism, Anorexia And Other Disorders?'),
#  ('1755', 'Parenting', 'Skills of Good Parents', '3.', '2013-06-13', 'skills-of-good-parents', 'None'),
#  ('1755', 'World News', 'Tourist Boat Sinks In Colombia With Nearly 160 On Board', 'At least six people died.', '2017-06-25', 'ferry-sinks-colombia', 'None'),
#  ('1757', 'Business', 'Workers Taking The Most Sick Days', 'Sick days are estimated to cost the U.', '2013-05-12', 'Unknown', ' 24/7 Wall St.'),
#  ('1757', 'Business', 'The Secrets of Publishing Success', 'When I started out, an author friend warned me that publishing was a crazy business, and he was right.', '2015-02-08', 'the-secrets-of-publishing', 'None'),
#  ('1758', 'Politics', "McCain's Advice To Trump", 'Sen.', '2017-11-02', 'mccains-advice-to-trump-stop-tweeting', " 'Stop Tweeting'"),
#  ('1754', 'Lifestyle', 'Do You Want a Relationship to Change?', 'It is amazing how most people say they want a solid relationship, but refuse to address how their thoughts create all sorts of relationship drama.', '2013-10-18', 'love-and-relationships', 'None'),
#  ('1754', 'Lifestyle', 'How Diet Can Bug Your Gut', 'The purpose of the study was to evaluate the potential relation between diet, microbiome and colorectal cancer risk.', '2013-06-12', 'gut-bacteria', 'None'),
#  ('1759', 'Business', "These Are America's Poorest States", 'The United States added 3.', '2015-09-25', 'Unknown', 'None'),
#  ('1756', 'Lifestyle', 'Dinner In 10', 'Just like a grilled cheese, but better.', '2013-03-14', 'croque-madame-recipe', ' Croque Madame'),
#  ('1757', 'Lifestyle', 'When Hope Is Under Attack', 'Close your eyes.', '2012-07-25', 'hope-faith', " Finding Guidance From Soul's Beauty"),
#  ('1758', 'Lifestyle', 'Hot Chefs', 'Superficially speaking, of course.', '2013-07-15', 'hot-chefs', ' A HuffPost Deathmatch'),
#  ('1758', 'Lifestyle', 'HuffPost Tastemakers', "It's swirly and has chocolate.", '2013-01-31', 'chocolate-swirl-milk-bar', ' New Item At Momofuku Milk Bar'),
#  ('1757', 'Politics', "It's A New Day For Democrats", 'For the first time in an entire year, millions of Democrats woke up hopeful Wednesday.', '2017-11-09', 'its-a-new-day-for-democrats', 'None'),
#  ('1757', 'Parenting', '15 (Kinda Sorta) Truths About Dinner', "Dinner will taste twice as good when it's eaten outside.", '2012-05-17', 'dinner', 'None'),
#  ('1758', 'Business', 'What Happens When Leaders Walk Their Talk', 'What leaders say is far less important than what they do.', '2014-07-11', 'what-happens-when-leaders', 'None'),
#  ('1754', 'Lifestyle', 'The Slightly Disgusting Origins of Haute Cuisine', 'To appreciate the sublime, the philosopher-politician Edmund Burke said was to appreciate terror in captivity.', '2013-09-20', 'haute-cuisine', 'None'),
#  ('1754', 'Lifestyle', 'Donut Flavors, In Order From Worst To Best (PHOTOS)', 'Which flavor is your favorite.', '2013-12-16', 'best-donut-flavor', 'None'),
#  ('1758', 'Business', 'These Are The Worst Sick Day Excuses We Have Ever Heard', '5.', '2013-10-26', 'sick-day-excuses-worst', 'None'),
#  ('1754', 'Lifestyle', 'Chocolate Peanut Butter Delights', "I love Reese's Peanut Butter Cups, but I may just have found a way to improve on them.", '2013-10-01', 'chocolate-peanut-butter-delights', 'None'),
#  ('1754', 'Lifestyle', 'Three Ways to Honor Rhubarb', 'Rhubarb shines all on its own.', '2013-06-04', 'three-ways-to-honor-rhuba', 'None'),
#  ('1755', 'Lifestyle', 'Eggs -- What Are You Really Getting for Your Dollar?', 'Eggs are, in a way, the perfect food.', '2012-03-31', 'eggs-health', 'None'),
#  ('1754', 'Lifestyle', 'Time for Autism Speaks to Zip It?', 'The young father continued to talk about about his boy in a tone I found both desperate and loving.', '2014-01-17', 'time-for-autism-speaks-to', 'None'),
#  ('1755', 'Politics', 'The Republican Horse Race Is Over, And Journalism Lost', 'Wrong, wrong, wrong — to the very end, we got it wrong.', '2016-05-05', 'Unknown', 'None'),
#  ('1754', 'Lifestyle', 'Peanut Butter Cookie Recipes To Try On National Peanut Butter Cookie Day', 'Happy National Peanut Butter Cookie Day.', '2013-06-12', 'peanut-butter-cookie-recipes', 'None'),
#  ('1754', 'Lifestyle', 'Manifesting 101', "Whenever I lecture on the how-to's of manifesting, there seems to be a lot of confusion about how to actually do it.", '2013-02-13', 'manifesting', 'None'),
#  ('1755', 'Business', 'Unequal Realities Inside The Jobs Report', "Today's U.", '2012-11-03', 'Unknown', 'None'),
#  ('1754', 'Parenting', "Why I Don't Make My Son Share", "There is a sharing policy at my son's preschool.", '2012-09-04', 'Unknown', 'None'),
#  ('1754', 'Lifestyle', 'The Key To A Good Nap (VIDEO)', "When you can't keep your eyes open for one more second do you reach for a coffee.", '2013-08-14', 'key-to-good-perfect-nap-video', 'None'),
#  ('1757', 'Politics', "Kim Davis Decides She's Actually A Republican", 'She was a longtime Democrat.', '2015-09-25', 'kim-davis-republican', 'None'),
#  ('1755', 'Parenting', '7 Postpartum Things I Totally Forgot About', 'First of all, a belated happy holidays from all of us.', '2013-01-03', 'Unknown', 'None'),
#  ('1756', 'Business', "Barbie's Biggest Threat", 'With her popularity waning, Barbie hit the road this week on a global campaign to burnish her brand.', '2013-05-19', 'Unknown', 'None'),
#  ('1754', 'Lifestyle', 'This Bloody Mary Is Bonkers, And Comes Topped With Roast Chicken And A Brownie', 'Get your belly ready (and head to Canada).', '2014-03-24', 'crazy-bloody-mary', 'None'),
#  ('1755', 'Lifestyle', 'Bok Choy Recipes', 'One of our favorite Chinese cooking staples.', '2013-07-29', 'bok-choy-recipes', ' A Taste Of China (PHOTOS)'),
#  ('1756', 'Parenting', 'Schools, Students and Guns', 'In Chardon, Ohio, T.', '2012-03-09', 'schools-students-guns', 'None'),
#  ('1754', 'Lifestyle', 'Homemade Fried Oreos Are Sinfully Delicious', "Easier than they look, and you don't even need a deep-fryer.", '2013-05-21', 'homemade-fried-oreos-reci', 'None'),
#  ('1756', 'Business', 'Beautiful Innovation Orphans', 'Innovation orphans need to be adopted.', '2014-06-30', 'beautiful-innovation-orph', 'None'),
#  ('1756', 'Lifestyle', 'An Early Spring Lunch', 'It poaches, it coddles, it fries, it binds, it rises, it aerates.', '2013-04-25', 'deviled-egg-salad', ' Deviled Egg Salad With Parsley'),
#  ('1757', 'Parenting', 'Why Mama Needs to Be Alone', 'Mama needs to be alone now.', '2014-02-21', 'why-mama-needs-to-be-alone', 'None'),
#  ('1756', 'Politics', 'Trump Describes Paris Terror Attack', 'There were 130 people killed that day.', '2018-05-04', 'trump-nra-paris-terror-attack', " 'Boom... Boom... Boom'"),
#  ('1757', 'World News', 'Russia Expels 2 American Diplomats', 'The U.', '2016-07-09', 'russia-expels-american-diplomats', 'None'),
#  ('1756', 'Lifestyle', 'Doughnut Plant Video', 'No one, and we mean no one, is better at doughnuts than the Doughnut Plant.', '2013-03-28', 'doughnut-plant-video', " Inside Mark Israel's New York City Kitchen"),
#  ('1756', 'Lifestyle', 'Cooking Off the Cuff', 'When your principal ingredient is no longer in season, consider simply leaving it out.', '2013-09-04', 'cooking-off-the-cuff-pepper-pancakes', ' Not Corn Pancakes - Pepper Pancakes'),
#  ('1756', 'Lifestyle', 'How Giving Thanks Will Help You Stress Less', 'The stress and strain of constantly being connected can sometimes take your life -- and your well-being -- off course.', '2013-11-28', 'thankful-mantras-quotes-gratitude', 'None'),
#  ('1756', 'Lifestyle', '5 Smart Reasons To Eat Eggs', 'While eggs have gotten a bad reputation for a long time due to cholesterol fears, evidence in the British Medical Journal.', '2014-04-13', 'eggs-health-benefits', 'None'),
#  ('1754', 'Lifestyle', 'Navigating Change', 'Change is in the air.', '2012-11-06', 'life-changes', 'None'),
#  ('1754', 'Lifestyle', 'All We Want For Christmas Is A Homemade Twinkie Machine (PHOTO)', 'Think green tea Twinkies.', '2013-12-11', 'homemade-twinkie-machine-photo', 'None'),
#  ('1756', 'Politics', 'Hillary Clinton Wins Missouri Democratic Primary', 'It was a razor-thin race that took two days to call.', '2016-03-16', 'hillary-clinton-missouri-primary', 'None'),
#  ('1755', 'Lifestyle', 'The Real Snack Food Story', 'Youth Radio.', '2013-02-28', 'the-real-snack-food-story', 'None'),
#  ('1756', 'Lifestyle', 'Facing Frailty at End of Life', 'My father does not want to die and I understand that.', '2012-06-27', 'end-of-life', 'None'),
#  ('1755', 'Lifestyle', 'Golden Globe Cocktails', 'Mix up a batch or two of these superb cocktails, throw on your heels, and let the awards season begin.', '2014-01-10', 'golden-globe-cocktails', 'None'),
#  ('1756', 'Lifestyle', 'Imbibe-Inspired Cinco de Mayo Eats and Drinks', 'Sunday is Cinco de Mayo.', '2013-05-03', 'imbibe-inspired-cinco-de', 'None'),
#  ('1757', 'Lifestyle', 'How to Get More Out of Giving', 'Giving is the antidote to stress.', '2013-08-27', 'benefits-of-giving', 'None'),
#  ('1755', 'Lifestyle', 'Who Has Time for That?', "It's not Marie Callender who will nourish your family to strength and wellness; it's you.", '2014-04-11', 'who-has-time-for-that', 'None'),
#  ('1758', 'Lifestyle', 'Ode to the Universe', 'The universe has your best interests at heart.', '2014-04-01', 'ode-to-the-universe', 'None'),
#  ('1758', 'Lifestyle', 'Friday the 13th -- Good Luck!', 'It is simply too dangerous to leave life to chance.', '2013-09-11', 'friday-13th', 'None'),
#  ('1755', 'Lifestyle', "Retail Clinics Could Help Reduce Hospital Readmissions -- As Long As They're Integrated With Hospitals", 'The U.', '2013-04-09', 'retail-clinics-hospital-readmissions', 'None'),
#  ('1755', 'Lifestyle', 'Finding Joy When it Seems Out of Reach', "When you have good reason to be stressed out, it's hard to make positive changes.", '2012-04-08', 'stress-tips', 'None'),
#  ('1759', 'Business', 'Report', 'The recommendations included imposing new controls on company spending, human resources and other areas where executives had wide discretion.', '2017-06-11', 'report-uber-board-to-discuss-ceo-kalanick-absence-policy-changes', " Uber Board Accept Holder's Recommendations, Discuss CEO Kalanick's Absence"),
#  ('1759', 'Politics', "Don't Believe The Hype", 'Reversing the policy is yet another Trump administration decision based on alternative facts.', '2017-08-28', 'dont-believe-the-hype-obamas-limited-restrictions-on-military-equipment-for-cops-were-reasonable', " Obama's Limited Restrictions On Military Equipment For Cops Were Reasonable"),
#  ('1759', 'Business', 'Women in Business Q&A', "Julie Yoo is a Co-Founder of Kyruus and serves as the company's Chief Product Officer.", '2015-02-22', 'women-in-business-qa-juli', ' Julie Yoo, Co-Founder & Chief Product Officer, Kyruus'),
#  ('1756', 'Lifestyle', '100 Percent Cheese Grilled Cheese', "It's all of our dreams come true.", '2013-02-25', 'all-cheese-grilled-cheese', 'None'),
#  ('1756', 'Lifestyle', 'Deep into Santa Cruz Mountains Wine Country at Fernwood Cellars', 'Talk about off the beaten path.', '2013-05-09', 'fernwood-cellars', 'None'),
#  ('1754', 'Lifestyle', 'Recipe Of The Day', 'A step up from banana bread.', '2012-10-25', 'banana-cake', ' Banana-And-Date Loaf'),
#  ('1756', 'Lifestyle', 'Reading Into Wrinkles', "WASHINGTON - Creases and furrows on someone's face may put a wrinkle in our ability to properly judge his or her emotions.", '2013-05-28', 'wrinkles-emotion-perception', ' How They Can Affect Our Perceptions Of Emotion'),
#  ('1756', 'Lifestyle', 'Dehydrator Recipes', 'Yes, you can make more than dried fruit in that thing.', '2013-09-18', 'dehydrator-recipes', ' Put This Kitchen Appliance To Use (PHOTOS)'),
#  ('1756', 'Lifestyle', 'Superfood Recipes', "You'll be healthy before you know it.", '2013-01-11', 'superfoods-recipes-healthy-eating', ' They Make Eating Healthy Easy (PHOTOS)'),
#  ('1756', 'Lifestyle', 'Stress-Free Cooking With Wine', "'I love to cook with wine, sometimes I even put it in the food.", '2012-12-11', 'stress-free-cooking-with-wine', ' Simple Recipes With A Few Sips In Between (PHOTOS)'),
#  ('1756', 'Lifestyle', 'HuffPost Tastemakers', "And it's beautiful.", '2013-03-07', 'yotam-ottolenghi-cooks', ' Ottolenghi Cooks With Colors'),
#  ('1756', 'Lifestyle', 'CFDA Health Initiative', 'To begin answering that question, and to take a broader look at the intersection of fashion and health, the CFDA moderated.', '2012-02-08', 'cfda-health-initiative-ar', ' Arianna, Industry Insiders Talk Intersection Between Fashion And Health'),
#  ('1756', 'Lifestyle', 'Cadbury Eggs vs. Peeps', 'This is not so much a question of which came first, but more so of which is better -- the chick(en) or the egg.', '2012-04-06', 'cadbury-eggs-vs-peeps', ' Which Is Better? (POLL)'),
#  ('1756', 'Lifestyle', 'Soup-A-Bowl', "Don't you think it's really hard to come up with a clever, fun, fundraising event.", '2013-11-01', 'soupabowl-a-fun-fundraise', ' A Fun Fundraiser!'),
#  ('1756', 'Lifestyle', 'Boston Marathon Runners', 'Still, David Yusko, a clinical psychologist who specializes in trauma and post-traumatic stress disorder at Penn Medicine.', '2013-04-16', 'boston-marathon-runners-explosion-aftermath', ' Experts Weigh In On Explosion Aftermath'),
#  ('1756', 'Lifestyle', 'Fearless Living Boot Camp, Day 19', 'What I know to be absolutely true is that NO ONE CAN BE FEARLESS ALONE.', '2012-09-28', 'fearless-living-boot-camp-19', ' Ask For Help! (VIDEO)'),
#  ('1757', 'World News', 'On his Santa Monica mountaintop, a billionaire envisions lofty thoughts on politics and culture', 'Nicolas Berggruen scuffs along a dirt road overgrown with foxtails, high in the Santa Monica Mountains.', '2016-05-02', 'Unknown', 'None'),
#  ('1756', 'Lifestyle', 'Field Notes From Newtown', 'We went to bed devastated Friday night and woke up on Saturday angry and afraid.', '2012-12-18', 'newtown-healing', ' Reflections on What Constitutes Good Care in a Time of Crisis')]

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET category = INITCAP(category)
# Out:
# 6000 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET category =
#     CASE WHEN category ='Food & Drink' THEN 'Lifestyle'
#         WHEN category = 'Wellness' THEN 'Lifestyle'
#         END
# WHERE category ='Food & Drink' or category = 'Wellness'
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# ALTER TABLE articles
# DROP CONSTRAINT articles_pkey
# Out:
# (psycopg2.errors.UndefinedObject) constraint "articles_pkey" of relation "articles" does not exist
#
# [SQL: ALTER TABLE articles
# DROP CONSTRAINT articles_pkey]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET article_key = LEFT(article_key,4)
# Out:
# 6000 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# ALTER TABLE articles
# ADD subtitle TEXT
# Out:
# (psycopg2.errors.DuplicateColumn) column "subtitle" of relation "articles" already exists
#
# [SQL: ALTER TABLE articles
# ADD subtitle TEXT]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET headline = SPLIT_PART(headline, ':', 1), subtitle = SPLIT_PART(headline, ':', 2)
# Out:
# 6000 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET subtitle =
#     CASE
#         WHEN subtitle = '' THEN 'None'
#         WHEN subtitle IS NULL THEN 'None'
#         END
# WHERE subtitle ='' or subtitle IS NULL
# Out:
# 6000 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET short_description = CONCAT(SPLIT_PART(short_description, '.', 1), '.')
# Out:
# (psycopg2.errors.UndefinedColumn) column "short_description" does not exist
# LINE 2: SET short_description = CONCAT(SPLIT_PART(short_description,...
#                                                   ^
#
# [SQL: UPDATE articles
# SET short_description = CONCAT(SPLIT_PART(short_description, '.', 1), '.')]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET keywords =
#     CASE
#         WHEN keywords IS NULL THEN 'Unknown'
#         END
# WHERE keywords IS NULL
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# ALTER TABLE articles
# ALTER COLUMN release_date SET DATA TYPE varchar(15)
# Out:
# (psycopg2.errors.UndefinedColumn) column "release_date" of relation "articles" does not exist
#
# [SQL: ALTER TABLE articles
# ALTER COLUMN release_date SET DATA TYPE varchar(15)]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# ALTER TABLE articles
# RENAME COLUMN short_description TO description
# Out:
# (psycopg2.errors.UndefinedColumn) column "short_description" does not exist
#
# [SQL: ALTER TABLE articles
# RENAME COLUMN short_description TO description]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# ALTER TABLE articles
# RENAME COLUMN release_date TO publish_date
# Out:
# (psycopg2.errors.UndefinedColumn) column "release_date" does not exist
#
# [SQL: ALTER TABLE articles
# RENAME COLUMN release_date TO publish_date]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///articles
#
# SELECT *
# FROM articles
# LIMIT 5
# Out:
# 5 rows affected.
# [('1758', 'Lifestyle', 'Recipe Of The Day', "It's one root vegetable you want to know.", '2013-03-01', 'jicama-recipes-salad', 'None'),
#  ('1757', 'World News', 'Turkey Removes Two Dozen Elected Mayors In Kurdish Areas', 'Police fired water cannons at protesters over the removals.', '2016-09-11', 'turkey-kurds-crackdown', 'None'),
#  ('1755', 'Lifestyle', 'What to Do with Leftover Halloween Candy', "There's going to be candy everywhere for days.", '2013-10-31', 'what-to-do-with-leftover', 'None'),
#  ('1755', 'Lifestyle', 'HIV/AIDS By The Numbers', '- Less than 100 children in the region became infected with HIV in 2011.', '2012-07-18', 'hiv-aids-numbers-statistics-worldwide', 'None'),
#  ('1754', 'Parenting', '7 Steps To Surviving A Road Trip With A Toddler', 'You know what can be fun.', '2013-03-11', 'Unknown', 'None')]

# %%
# %%sql
# postgresql:///articles
#
# UPDATE articles
# SET publish_date =(publish_date :: date)
# Out:
# 6000 rows affected.
# []

# %%
# %%sql
# postgresql:///articles
#
# SELECT article_key, category, headline,
#         subtitle, description,keywords, to_char(publish_date :: date, 'Mon DD, YYYY') as publish_date
# FROM (SELECT *
#         FROM articles
#         WHERE article_key = '1754' AND publish_date BETWEEN '2014-01-01' AND '2015-12-31'
#         ORDER BY publish_date ) as articles
# Out:
# 188 rows affected.
# [('1754', 'Lifestyle', "21 Weird Foods You'll Serve In 2014", 'None', 'Your dinner plate is going global in 2014.', 'Unknown', 'Jan 03, 2014'),
#  ('1754', 'Parenting', 'Life-Giving Parenting', 'None', 'I intend to converse with my children in a life-supporting fashion.', 'lifegiving-parenting', 'Jan 06, 2014'),
#  ('1754', 'Parenting', 'Danielle Jonas', 'None', 'Watch the full segment with Danielle Jonas on HuffPost Live.', 'danielle-jonas-anxiety-medication-pregnancy', 'Jan 08, 2014'),
#  ('1754', 'Lifestyle', 'Jessica Metzger Lost 110 Pounds On The Quest To Become Her Best Self', 'None', 'I do not follow a specific meal plan, I do not eat 100 percent clean and I no longer track my calories.', 'i-lost-weight-jessica-metzger', 'Jan 10, 2014'),
#  ('1754', 'Parenting', "The Christmas I'll Carry", 'None', 'For me, it seems that to honor the holiday, I must honor the everyday.', 'the-christmas-ill-carry', 'Jan 10, 2014'),
#  ('1754', 'Parenting', '6 Reasons Why Newborns Have Stuffy Noses', 'None', "What many first-time parents don't realize is that newborns usually sound stuffy when they breathe.", 'why-newborns-have-stuffy-noses', 'Jan 16, 2014'),
#  ('1754', 'Parenting', 'Flipping the Gridiron', 'None', 'When I met my husband 14 years ago, he turned me into a football fan.', 'flipping-the-gridiron-tackling-my-sons-obsession-with-football', 'Jan 17, 2014'),
#  ('1754', 'Lifestyle', 'Time for Autism Speaks to Zip It?', 'None', 'The young father continued to talk about about his boy in a tone I found both desperate and loving.', 'time-for-autism-speaks-to', 'Jan 17, 2014'),
#  ('1754', 'Lifestyle', 'Unexpected Results From an Unexpected Resolution', 'None', "I usually don't go for New Year's resolutions, but I'm glad we did this one.", 'living-will', 'Jan 17, 2014'),
#  ('1754', 'Lifestyle', 'Narcissists May Be More Likely To Be Leaders (But Not Necessarily Good Ones)', 'None', 'Indeed, a 2012 study Harms authored in the Journal of Applied Social Psychology showed that narcissists make better first.', 'narcissists-leaders', 'Jan 21, 2014'),
#  ('1754', 'Lifestyle', 'Blood Test Could Help Identify Pancreatic Cancer Early', 'None', 'Pancreatic cancer could be identified in its early stages with a test that looks for genetic material in the blood, according.', 'pancreatic-cancer-blood-test', 'Jan 21, 2014'),
#  ('1754', 'Lifestyle', 'How The Most Powerful People In The World Define Healthy Living', 'None', 'These leaders will also be focusing on their own health this week, using fitness trackers and being encouraged to make healthy.', 'how-the-most-powerful-peo', 'Jan 22, 2014'),
#  ('1754', 'Business', 'What Should HR Leaders Focus On in 2014?', 'None', 'The most important thing that HR should focus on in talent management is assessing the skills the organization needs to implement its strategy, and the plan for recruiting and managing that critical talent.', 'what-should-hr-leaders-fo', 'Jan 26, 2014'),
#  ('1754', 'Lifestyle', 'Cure vs. Remission', 'None', "Until researchers find a cure Crohn's disease and ulcerative colitis, I implore you -- please don't say these diseases can be cured when they can't.", 'personal-health', 'Jan 29, 2014'),
#  ('1754', 'Lifestyle', 'Can We Change Our Culture of Burnout?', 'None', "I'm empathic to those caught in the burnout vortex.", 'can-we-change-our-culture', 'Jan 29, 2014'),
#  ('1754', 'Parenting', 'Pick-Up Lines My 6-Year-Old Son Uses to Impress Much Older Waitresses', 'None', "Did you know that I'm 6 years old.", 'pick-up-lines-my-6-year-old-son-uses-to-impress-much-older-waitresses', 'Jan 30, 2014'),
#  ('1754', 'Business', 'China Now Guzzles More Red Wine Than Any Other Country In The World', 'None', 'Part of China’s growing appetite for red wine is the country’s taste for certain French varietals.', 'china-red-wine', 'Feb 02, 2014'),
#  ('1754', 'Business', 'Countries Where Children Have the Best Opportunities', 'None', 'Is America really the land of opportunity.', 'Unknown', 'Feb 02, 2014'),
#  ('1754', 'Lifestyle', 'The Midwest Officially Has Some Of The Best Beers In The World', 'None', 'If you want the best English pale ale, go to England.', 'best-beers-midwest-ratebeer', 'Feb 06, 2014'),
#  ('1754', 'Lifestyle', '5 Surprising Ways Your Mattress Affects Your Sleep And Health', 'None', "Not that we don't recognize the importance of a comfy mattress.", 'mattress-sleep-health', 'Feb 09, 2014'),
#  ('1754', 'Parenting', 'The Importance of Modeling the Behavior You Want to See', 'None', "Many parents turn to professionals thinking that when their teen hears about the dangers of drug use from someone else, they will be swayed, but the truth is that usually, it's the parents' behavior that have much more impact on a teen's behavior.", 'the-importance-of-modeling-the-behavior-you-want-to-see', 'Feb 11, 2014'),
#  ('1754', 'Lifestyle', 'The Most Romantic Restaurants in America', 'None', 'Your wooing efforts may fall flat if half of the dinner conversation revolves around the disappointing food.', 'the-most-romantic-restaur', 'Feb 12, 2014'),
#  ('1754', 'Lifestyle', "The Essential Russell Stover's Valentine's Day Cheat Sheet", 'None', "We can save you the heartache and pain of biting into random chocolates you don't like, thanks to our heart-shaped chocolate cheat sheet.", 'the-essential-russell-sto', 'Feb 13, 2014'),
#  ('1754', 'Parenting', "Son's Grades Slipping", 'None', 'The transition to middle school is a big one.', 'sons-grades-slipping-is-it-add', 'Feb 13, 2014'),
#  ('1754', 'Lifestyle', "13 Signs You Have Anxiety -- And Don't Know It", 'None', 'Just as some people feel depressed in the winter, some feel anxious.', 'Unknown', 'Feb 16, 2014'),
#  ('1754', 'Lifestyle', "Why I'm Not Worried About Yoga Mat Chemicals in My Food", 'None', 'We have been eating fast food sandwiches made with azodicarbonamide for years.', 'azodicarbonamide-subway', 'Feb 19, 2014'),
#  ('1754', 'Lifestyle', 'The Long Winter of Grief', 'None', 'The process of grief is sometimes likened to a cold, dark period of gloom.', 'death-and-dying', 'Feb 21, 2014'),
#  ('1754', 'Lifestyle', 'Dare to Be 100', 'None', "A minute's reflection reveals that such a relationship must be.", 'dare-to-be-100-an-importa', 'Feb 23, 2014'),
#  ('1754', 'Lifestyle', 'Paula Deen Riding Things 2.0', 'None', "And she's back in the game.", 'Unknown', 'Feb 24, 2014'),
#  ('1754', 'Lifestyle', 'FDA Approves Drug For Rare Body Fat Disorder', 'None', 'The drug, Myalept (metreleptin), is a form of leptin meant to reduce accumulation of fat in organs to better control blood.', 'leptin-hormone-deficiency-drug-rare-body-fat-disorder-treatment-fda', 'Feb 25, 2014'),
#  ('1754', 'Lifestyle', 'Sadly, Tech Addicts Have Taken a Page From Drug Abusers', 'None', 'In essence, whenever intensely-pleasurable and arousing substances, like cocaine and crystal meth, or experiences, like shopping, video-gaming, gambling and sex, become more readily affordable and accessible, the potential for addiction rears its ugly head.', 'tech-addiction', 'Feb 26, 2014'),
#  ('1754', 'Lifestyle', 'How to Break Down A Butternut Squash', 'None', "It's time to end the struggle.", 'how-to-break-down-a-butte', 'Feb 26, 2014'),
#  ('1754', 'Lifestyle', 'Bake the Best Macaroni and Cheese', 'None', "Glenn Harris, chef of The Smith in New York City, doesn't cut back on the butter in his iconic macaroni and cheese recipe.", 'bake-the-best-macaroni-an', 'Feb 27, 2014'),
#  ('1754', 'Lifestyle', 'If Your Cat Is Fat, Try a High-Moisture Diet', 'None', "Not All Canned Cat Food is Equally Nutritious If your budget can't accommodate human grade or even premium canned cat food.", 'if-your-cat-is-fat-try-a', 'Feb 27, 2014'),
#  ('1754', 'Business', 'Doing Business in the United Kingdom', 'None', "When traveling abroad, it's important to learn about the people and culture you are doing business with, so as not to be misunderstood or appear rude.", 'doing-business-in-the-uni', 'Mar 01, 2014'),
#  ('1754', 'Parenting', 'Kids React To Rotary Phones And Make You Feel Like The Dinosaur You Are', 'None', 'These smart kiddos know that the object in front of them is a phone because of history books and old-time movies.', 'kids-react-to-rotary-phon', 'Mar 03, 2014'),
#  ('1754', 'Lifestyle', 'Get Fit Fast', 'None', 'You get more fat loss with alternating medium or high intensity activity with periods of rest than training for the same.', 'interval-training', 'Mar 04, 2014'),
#  ('1754', 'Parenting', 'The Cost of Internet Defamation', 'None', 'With the electronic frontier evolving, online defamation has reared an ugliness that has ruined lives both emotionally and financially.', 'the-cost-of-internet-defamation', 'Mar 05, 2014'),
#  ('1754', 'Lifestyle', 'Cloudy With a Chance of Meatheads', 'None', 'As long we impart to nutrition the mediagenic volatility associated with the weather, we can all but guarantee that our understanding of what is good for us will remain very much clouded over.', 'diet-and-nutrition', 'Mar 05, 2014'),
#  ('1754', 'Lifestyle', "We Can't Even With Martha Stewart's Sex Advice", 'None', 'Want to read more from HuffPost Taste.', 'martha-stewart-reddit-ama-sex-advice', 'Mar 06, 2014'),
#  ('1754', 'Lifestyle', '5 Things That Scare Me Most About Stress', 'None', "Stress alone doesn't makes you a better, stronger person.", 'dealing-with-stress', 'Mar 06, 2014'),
#  ('1754', 'Lifestyle', "The 21 New York Restaurants I'll Miss The Most When I Move To LA", 'None', "After 15 years in the Tri-State Area, I'm moving to LA.", 'new-york-restaurants-ill-miss-the-most', 'Mar 06, 2014'),
#  ('1754', 'Lifestyle', 'Bubbles Rising', 'None', 'An increasing number of excellent Santa Barbara area producers are trying their hand at creating delicious sparkling wines.', 'bubbles-rising-sparkling', 'Mar 07, 2014'),
#  ('1754', 'Parenting', "He Said, 'I Think Your Baby Has Dwarfism'", 'None', "When you don't see it coming at all, it will feel like you are blindsided.", 'he-said-i-think-your-baby-has-dwarfism', 'Mar 07, 2014'),
#  ('1754', 'Lifestyle', 'Dinner Tonight', 'None', "Crab Mac, if you haven't had it, is a Monday kind of dish: rich, comforting, and laced with salty bits of crab and prosciutto.", 'dinner-tonight-crab-mac', 'Mar 09, 2014'),
#  ('1754', 'Lifestyle', '9 Steps to Overcoming Fear', 'None', "Fear is something you can have, that's true -- but fear isn't of you.", '9-steps-to-overcoming-fea', 'Mar 10, 2014'),
#  ('1754', 'Parenting', "About That ‘Common Core' Math Problem Making the Rounds on Facebook...", 'None', 'Over the past week, I’ve seen this image multiple times on Facebook and elsewhere, a supposed denunciation of the Common.', 'Unknown', 'Mar 11, 2014'),
#  ('1754', 'Parenting', "Why I Won't Ban 'Bossy'", 'None', 'The great misstep with this campaign and others like it is suggesting, even in jest, that we limit one freedom to solve a problem.', 'why-i-wont-ban-bossy', 'Mar 12, 2014'),
#  ('1754', 'Lifestyle', 'Get Out of the War', 'None', 'See the suffering in the other people and yourself, and see if you can have compassion for all parties.', 'get-out-of-the-war', 'Mar 12, 2014'),
#  ('1754', 'Lifestyle', 'My Day as a Test Case for Self-Compassion', 'None', "That's when I saw it.", 'my-day-as-a-test-case-for', 'Mar 14, 2014'),
#  ('1754', 'Business', 'The Best And Worst Paying Cities For Women', 'None', 'Despite improving since the 1960s, the gender pay gap is still quite wide in the United States.', 'Unknown', 'Mar 15, 2014'),
#  ('1754', 'Lifestyle', 'Open-faced Avocado Hummus Sandwich With Pickled Shallots and Baby Spinach', 'None', "Here's a sandwich that's easy to assemble, healthy and quite spunky.", 'open-face-avocado-hummus', 'Mar 18, 2014'),
#  ('1754', 'Lifestyle', "The Spring Vegetables We're So Excited For", 'None', 'Bring it on, spring.', 'spring-vegetables', 'Mar 20, 2014'),
#  ('1754', 'Parenting', "The Problem With 'It's Not Fair!'", 'None', 'Fair does not mean equal.', 'the-problem-with-its-not-fair', 'Mar 20, 2014'),
#  ('1754', 'Lifestyle', 'Can Sleep Science Help You Pick a Perfect March Madness Bracket?', 'None', 'As a sleep specialist, helping elite athletes deal with sleep and travel is what I do for a living.', 'sleep-tips', 'Mar 20, 2014'),
#  ('1754', 'Lifestyle', 'QUIZ', 'None', 'From tequila to bourbon, find out where your favorite booze originated.', 'booze-comes-from', 'Mar 21, 2014'),
#  ('1754', 'Lifestyle', 'This Bloody Mary Is Bonkers, And Comes Topped With Roast Chicken And A Brownie', 'None', 'Get your belly ready (and head to Canada).', 'crazy-bloody-mary', 'Mar 24, 2014'),
#  ('1754', 'Lifestyle', 'Leave No (Kidney) Stone Unturned', 'None', 'March is National Kidney Month and the National Kidney Foundation encourages people to learn about the kidneys and kidney-related conditions, including kidney stones.', 'national-kidney-month', 'Mar 24, 2014'),
#  ('1754', 'Lifestyle', "Starbucks vs. Dunkin'", 'None', "Not too surprisingly, Dunkin' Donuts is New England's coffee chain of choice -- Bostonians' love for Dunkies will never, ever.", 'coffee-chains-starbucks-dunkin', 'Mar 25, 2014'),
#  ('1754', 'Parenting', "My Daughter's Olympic Dream", 'None', 'I felt I did the right thing, but still.', 'my-daughters-olympic-dream', 'Mar 28, 2014'),
#  ('1754', 'Parenting', 'March Madness for College Admissions Decisions', 'None', 'Just as the top college basketball teams are competing their way towards the April 7 National Championship Game, so are high schools seniors as they learn which colleges have accepted, waitlisted or rejected them.', 'march-madness-for-college', 'Mar 29, 2014'),
#  ('1754', 'Lifestyle', '2 Cases Of Ebola Confirmed In Liberia', 'None', 'The suspected spread of disease into Liberia and Sierra Leone has stirred concern that one of the most lethal infectious.', 'ebola-liberia', 'Mar 30, 2014'),
#  ('1754', 'Lifestyle', 'FDA Approves Oral Drug For Grass Allergy', 'None', 'Oralair was approved in the European Union in 2008 and is also sold in Canada, Australia and Russia for the treatment of.', 'grass-allergy-drug-oralair', 'Apr 01, 2014'),
#  ('1754', 'Parenting', 'The Spring F-Word', 'None', 'Like many of you, my family has a rhythm, and spring forward rocks us to our core.', 'spring-fword', 'Apr 01, 2014'),
#  ('1754', 'Lifestyle', 'Cooking Off the Cuff', 'None', "It's amazing how inspiring leftover spuds can be, don't you think.", 'cooking-off-the-cuff-pota', 'Apr 02, 2014'),
#  ('1754', 'Parenting', 'Your Biological Clock Turns Cuckoo Earlier Than You Think', 'None', "Knowledge, as they say, is power, and even if you're not seeing anyone special, staying on top of your fertility can only serve you in the long run.", 'your-biological-clock-turns-cuckoo-earlier-than-you-think', 'Apr 02, 2014'),
#  ('1754', 'Parenting', 'Toddler Has No Clue This Basketball Hoop Is Actually Just A Cardboard Box', 'None', 'He shoots.', 'toddler-cardboard-basketball-hoop', 'Apr 03, 2014'),
#  ('1754', 'Lifestyle', 'The Food Hall Revolution', 'None', "Forget what you know about the food court; there's a new definition on the rise.", 'the-food-hall-revolution', 'Apr 03, 2014'),
#  ('1754', 'Parenting', "Probiotics Don't Reduce The Rate Of Colic In Babies (STUDY)", 'None', "The probiotic also showed no benefits for family or maternal well-being, or infant sleep, and didn't alter the babies' gut.", 'probiotics-dont-help-babies-with-colic', 'Apr 03, 2014'),
#  ('1754', 'Parenting', 'Facebook Friends Help Diagnose A 3-Year-Old With Eye Disease', 'None', "Two of Taylor's Facebook friends pointed that out and said something seemed off.", 'facebook-helps-3-year-old-with-eye-disease', 'Apr 04, 2014'),
#  ('1754', 'Lifestyle', 'Autism Awareness and Advocacy in Our Community', 'None', 'While autism is a condition affecting people in all sectors of society, socioeconomic disparities influence its diagnosis and treatment among African-Americans.', 'autism-minorities', 'Apr 04, 2014'),
#  ('1754', 'Lifestyle', 'Wheelchair Wisdom', 'None', 'Discovering the Calm and Stillness I came of age as part of the Woodstock generation and the Age of Aquarius, seeking a new.', 'wheelchair-wisdom-keep-st', 'Apr 04, 2014'),
#  ('1754', 'Lifestyle', 'The AROMAFORK™ Will Make Your Food Taste Better. Seriously.', 'None', 'This could change everything.', 'aromafork', 'Apr 08, 2014'),
#  ('1754', 'Parenting', 'Women Collaborate to Achieve Success', 'None', "I've been writing professionally for a long time now, taking breaks here and there to procreate, and I can tell you that I would not be as far along in my career if it weren't for a network of women who have helped me along the way, just as I've helped them.", 'women-collaborate-to-achieve-success-an-interview-with-jen-mann', 'Apr 09, 2014'),
#  ('1754', 'Lifestyle', 'Are You Drinking Drugs?', 'None', "Because the pharmaceuticals register in such small amounts -- measured in parts per billion, in some cases -- health officials aren't worried about the risk to humans.", 'drinking-water', 'Apr 09, 2014'),
#  ('1754', 'Lifestyle', 'High-Fat Diet Increases Breast Cancer Risk, Study Finds', 'None', 'Although the study indicates that as more saturated fat is consumed, the risk of breast cancer steadily rises, Hirshfield.', 'high-fat-diet-breast-cancer', 'Apr 10, 2014'),
#  ('1754', 'Lifestyle', "Sriracha, Sapporo and 17 Other Food Brand Names You're Probably Mispronouncing", 'None', 'Is it Sa-POE-roe or SA-poe-roe.', 'sriracha-sapporo-and-17-m', 'Apr 10, 2014'),
#  ('1754', 'Lifestyle', '10 Animals Who Remind Us To Stop And Smell The Roses', 'None', 'For more GPS Guides, click here.', 'stop-and-smell-the-roses', 'Apr 10, 2014'),
#  ('1754', 'Lifestyle', 'These Countries Are So Much Better Than America When It Comes To Work-Life Balance', 'None', 'In France, that concern is being taking seriously.', 'why-other-countries-are-s', 'Apr 11, 2014'),
#  ('1754', 'Lifestyle', 'Olive Oil-Thyme Bundt Cake With Candied Meyer Lemon Peels and Citrus Compote', 'None', "Who doesn't love the look of a Bundt cake.", 'olive-oil-thyme-bundt-cak', 'Apr 15, 2014'),
#  ('1754', 'Lifestyle', 'Berry Coconut Frozen Yogurt', 'None', 'Berry Coconut Frozen Yogurt is the flirty little sundress of desserts.', 'berry-coconut-frozen-yogurt', 'Apr 15, 2014'),
#  ('1754', 'Lifestyle', '19 Ideas For A Healthier Easter Basket', 'None', 'The Easter Bunny is the bearer of all things sweet, delicious and right with the world.', 'Unknown', 'Apr 16, 2014'),
#  ('1754', 'Lifestyle', "You've Been Cutting Tomatoes Wrong, But This Hack Shows You To Cut Them Like A Ninja (VIDEO)", 'None', "You'll be face palming in no time.", 'cut-tomatoes-ninja-cooking-hack', 'Apr 16, 2014'),
#  ('1754', 'Lifestyle', 'Yes, The Chia Seeds You Eat Are The Same Ones That Grow On Chia Pets', 'None', "It's a little disturbing.", 'chia-seeds', 'Apr 17, 2014'),
#  ('1754', 'Politics', 'What Democrats Must Do to Win in November', 'None', 'This November, Democrats will have chance to reconnect with ethnic voters and win support from them while still courting other key groups.', 'what-democrats-must-do-to', 'Apr 19, 2014'),
#  ('1754', 'Business', 'Top 5 Tips for Helping Lead a Productive and Happy Team', 'None', 'I am managing a team of 11.', 'top-five-tips-for-helping-leadership', 'Apr 28, 2014'),
#  ('1754', 'Business', 'Class of 2014', 'None', "You've got your diploma and a killer new job, now all you need to do is find a place to live.", 'class-of-2014-tips-for-re', 'May 16, 2014'),
#  ('1754', 'Business', 'Teens and the Summer Job', 'None', "I've read articles knocking the teen sector for their lack of willingness to find a summer gig; but every young person I've encountered wants a summer job because they want money.", 'teens-and-the-summer-job', 'May 20, 2014'),
#  ('1754', 'Politics', 'Bring on the Prosperity!', 'None', 'On Monday, Obama will announce new rules to reduce carbon pollution from power plants.', 'bring-on-the-prosperity', 'May 30, 2014'),
#  ('1754', 'World News', "Stunting Stalls in Timor-Leste, Exposing 'Human Infrastructure' Investment Gap", 'None', 'A 2013 UNICEF report listed Timor-Leste as having the highest percentage of children under five who are moderately or severely stunted in the world, matched only by Burundi.', 'stunting-stalls-in-timorl', 'Jun 03, 2014'),
#  ('1754', 'World News', 'Fatah and Hamas', 'None', 'Barely had the pictures of the Palestinian unity government been published, when skirmishes broke out around ATMs in Gaza between Hamas and Fatah government workers.', 'fatah-and-hamas-spontaneo', 'Jun 07, 2014'),
#  ('1754', 'Business', 'Think Summer Hours Are Enough to Make People Happy?', 'None', "While you may think giving your staff a couple of extra hours of free time a week is feeding their souls, you're wrong.", 'think-summer-hours-are-en', 'Jun 13, 2014'),
#  ('1754', 'World News', 'The Party and the Army', 'None', 'Today, eight ministries are led by career military officers, three of whom are still on active duty.', 'the-party-and-the-army-ci', 'Jun 26, 2014'),
#  ('1754', 'World News', 'Youth, Television and What Might Keep Afghanistan from Ending up Like Iraq', 'None', 'Ever since the Islamic State of Iraq and Syria (ISIS) began their recent offensive in Iraq, anxieties about the potential of something similar taking place in Afghanistan have abounded.', 'youth-television-and-afghanistan', 'Jul 09, 2014'),
#  ('1754', 'World News', 'America Needs to Change Its Failed Iraq-Iran Policy', 'None', 'Preaching democratic values while engaging in supporting undemocratic and repressive regimes has never enhanced American credibility, and it has rarely been a successful security tactic in the long term.', 'america-needs-to-change-i', 'Jul 18, 2014'),
#  ('1754', 'World News', 'Gaza and Palestinian Leadership', 'None', 'Back in  June, 1967, the second day of the Six Day War, I became the first foreign correspondent to enter Gaza City when Israeli troops took that forsaken piece of real estate from Egyptian control.', 'gaza-and-palestinian-leadership', 'Jul 22, 2014'),
#  ('1754', 'Business', 'Your Career - Paved Road or Tall Grass?', 'None', 'Imagine a time in your career when the road ahead seems seems perfectly clear.', 'do-you-want-to-walk-a-pav', 'Jul 24, 2014'),
#  ('1754', 'Business', 'Dining Etiquette', 'None', 'Pick and choose with caution.', 'dining-etiquette-7-foods-job-interview', 'Jul 30, 2014'),
#  ('1754', 'World News', 'On Centennial, Seven Harvard Scholars List Lessons of WWI -- And How They Might Apply Today', 'None', 'This week marks the centennial of the outbreak of World War I.', 'wwi-centennial-lessons', 'Jul 31, 2014'),
#  ('1754', 'World News', 'Mother Courage in Israel, Gaza, Iraq, Syria and the Ukraine', 'None', "There's a disconnect between armies and ideologies and those who bear the burden of conflicts like those raging in Israel, Gaza, Iraq, Syria and the Ukraine.", 'mother-courage-in-israel-', 'Aug 07, 2014'),
#  ('1754', 'Business', 'Interruption Rich', 'None', 'When combined with multiple electronic communication systems an interruption-rich work environment is created.', 'interruption-rich', 'Aug 19, 2014'),
#  ('1754', 'Business', 'Being of Service', 'None', 'Value is what attracts and retains\xa0customers and employees.', 'being-of-service-why-mean', 'Aug 20, 2014'),
#  ('1754', 'Business', 'Legacy Wars', 'None', "Not long ago, Malcolm Gladwell made a bold prediction: Fifty years from now, Apple will be around and Microsoft will be gone, but Bill Gates will be remembered -- and Steve Jobs won't.", 'legacy-wars-steve-jobs-vs', 'Aug 25, 2014'),
#  ('1754', 'Business', 'The Mysteries of Inequality Are Only Mysterious to Elites', 'None', 'We have the central bank of the US acting deliberately to keep workers from getting pay increases.', 'the-mysteries-of-inequali', 'Sep 23, 2014'),
#  ('1754', 'Business', 'Hardly Strictly Warren Hellman', 'None', "For inspiration on how to manage the flexibility that accompanies Phase 4 of the Four Phases of Startup Life -- the What's Next.", 'hardly-strictly-warren-he', 'Sep 29, 2014'),
#  ('1754', 'World News', 'Remembering my Interview with Jean-Claude Duvalier', 'None', "Until the last minute I didn't believe it would happen.", 'remembering-my-interview-', 'Oct 06, 2014'),
#  ('1754', 'Business', "Protect Your Franchise from the Same Fate as McDonald's", 'None', "The National Labor Relations Board's recent ruling labeling McDonald's as a joint employer of their franchisees struck a current of fear into most franchisors.", 'protect-your-franchise-fr', 'Oct 15, 2014'),
#  ('1754', 'Business', 'How to Have More Money, Time, Fun and Happiness, Overnight and Guaranteed!', 'None', "Plan out your dream and then damn well go and do the dream because I think we're both adult enough to accept that planning dreams does little to nothing to make them come true if you don't also take now action on those dreams, yeah.", 'how-to-have-more', 'Oct 16, 2014'),
#  ('1754', 'World News', 'Send in the Air Force Combat Controllers and Green Berets to Destroy ISIS.', 'None', 'As Rome (or at least Kobani) burns and faces the very real threat of a Srebrenica-style massacre, it is time for the US to stop fiddling and entertain the idea of putting small groups of US troops into the fray to empower our Kurdish peshmerga, Free Syrian Army and Iraqi government allies.', 'send-in-the-air-force-com', 'Oct 22, 2014'),
#  ('1754', 'Business', "Embracing 'Showrooming'", 'None', "You can't fight the Internet and you can't bite the hand that feeds you.", 'embracing-showrooming', 'Oct 23, 2014'),
#  ('1754', 'Politics', 'If (When) Baghdad Falls, Keep American Soldiers Away From the Mess Created By Bush and Obama', 'None', "With Iraq falling apart and a new enemy on the horizon that's simply a rebranding of the old one, there's a striking observation to be made about two presidents, Congress, and the leaders who send our soldiers off to war.", 'if-when-baghdad-falls-kee', 'Oct 24, 2014'),
#  ('1754', 'Politics', 'Is Bipartisanship Possible?', 'None', 'Voters in many communities continue to be subjected to wave after wave of negative political ads.', 'is-bipartisanship-possibl', 'Nov 01, 2014'),
#  ('1754', 'Politics', 'The Power of Your Vote', 'None', "The Koch's tidal wave of money can corrupt our democracy, but we must not abet it with our silence.", 'the-power-of-your-vote', 'Nov 03, 2014'),
#  ('1754', 'Business', 'Is Job Hunting During the Holidays a Waste of Time?', 'None', 'Because so many job seekers slack off during the end of the year, for the holidays or just because they have more to do in their personal lives, fewer job seekers go after every job.', 'is-job-hunting-during-the', 'Nov 06, 2014'),
#  ('1754', 'Business', 'Super Majority Without The Super Power', 'None', "Recognizing the power of the purse and the women who carry them should be a priority for companies if they are going to tap their respective market's full potential.", 'super-majority-without-th', 'Nov 11, 2014'),
#  ('1754', 'Politics', 'Illogical Logic of Our Iraq Policy', 'None', 'We are back again in Iraq except that this time we are also bombing another sovereign nation, Syria, to remove ISIS even though it is not a direct threat to the U.', 'reluctant-warrior', 'Nov 17, 2014'),
#  ('1754', 'Business', "AT&T's--REDACTED--to the FCC's Requests about--REDACTED--Fiber Optic Deployment--REDACTED.", 'None', "AT&T must be investigated for its previous failures to fulfill basic commitments in prior mergers, especially the AT&T-BellSouth merger and the FCC should audit the new proposed fiber optic plans, not just take AT&T's word for it.", 'attsredactedto-the-fccs-r', 'Nov 28, 2014'),
#  ('1754', 'Business', "It's 2015. How Are We Still Having These Conversations?", 'None', "The person kicking ass in a negotiation might have ovaries, but that doesn't require her to smile sweetly and make sure everyone is okay with the outcome of the deal.", 'its-2015-how-are-we-still', 'Dec 14, 2014'),
#  ('1754', 'Business', 'Being Vulnerable in Business Can Be a Good Thing', 'None', "Most of us fundamentally believe if we show the vulnerable side of ourselves, our clients, employees and partners won't want to work with us and our business will be seen as a failure.", 'being-vulnerable-in-business-can-be-a-good-thing', 'Dec 17, 2014'),
#  ('1754', 'World News', 'President Obama Has Created A Dangerous Precedent In Cuba', 'None', 'President Obama not only handed Castro a huge propaganda victory, but also created a dangerous precedent by signaling our enemies that major policy concessions can be gained by taking an American hostage.', 'hope-in-change-is-not-a-v', 'Jan 10, 2015'),
#  ('1754', 'World News', "PK -- A Masterstroke Off Hirani's Canvas", 'None', 'Khan and his versatility never fails to impress.', 'pk-a-masterstroke-off-hir', 'Jan 12, 2015'),
#  ('1754', 'World News', 'Washington Is Well As Others Are Implicated In Their Wars', 'None', "What was absent in President Barack Obama's State of the Union Address was more intriguing than what he mentioned, in relation to international conditions, and the positions of the United States on them.", 'washington-is-well-as-oth', 'Jan 23, 2015'),
#  ('1754', 'World News', 'Weekend Roundup', 'None', 'The WorldPost was launched one year ago in Davos.', 'weekend-roundup-50', 'Jan 24, 2015'),
#  ('1754', 'Business', 'Rupert Murdoch, Are You OK?', 'None', 'What is the billionaire media magnate trying to tell us.', 'rupert-murdoch-ambivalent-tweet-drama', 'Jan 27, 2015'),
#  ('1754', 'Business', '32 Effective Formats to Package Your Systems', 'None', 'Have you ever been frustrated that your staff has ignored the step-by-step systems you created to lead them through a defined process.', '32-effective-formats-to-p', 'Jan 30, 2015'),
#  ('1754', 'Politics', 'Will Congress OK War Without Limits?', 'None', 'The specter of the Islamic State has silenced congressional criticism and marginalized anti-war voices on the outside.', 'will-congress-ok-war-with', 'Feb 03, 2015'),
#  ('1754', 'Business', 'Women in Business Q&A', 'None', 'Betsy Myers is the founding director of The Center for Women and Business at Bentley University.', 'women-in-business-qa-bets', 'Feb 07, 2015'),
#  ('1754', 'Business', 'From Uniform & Impersonal to Personalized and Targeted', 'None', 'Sports consumption is inherently personal, and ESPN has leveraged this to provide greater relevance for their user and a greater audience for their own content.', 'from-uniform-impersonal-t', 'Feb 10, 2015'),
#  ('1754', 'Business', 'Will the United States End Up Like Greece? The Risks of the Trans-Pacific Partnership', 'None', 'For years people have been running around Washington yelling that the United States was at risk of becoming Greece.', 'will-the-united-states-en', 'Feb 10, 2015'),
#  ('1754', 'Business', 'Urban Headwinds, Suburban Tailwinds', 'None', 'Although home prices are rising faster in urban neighborhoods, population is growing faster in suburban neighborhoods.', 'urban-headwinds-suburban-tailwinds', 'Feb 11, 2015'),
#  ('1754', 'World News', 'Diversity Education to Promote Tolerance', 'None', 'While privileged and generally very expensive schools around the globe bank on diversity through both their internationally recognized curriculums and extracurricular activities like Model United Nations, the accessibility to such resources lacks in mainstream schools in most countries.', 'diversity-education-to-pr', 'Feb 16, 2015'),
#  ('1754', 'World News', "From Megawatts to Gigawatts -- India's Swach Shakti Moment", 'None', 'So India can have its Swach Shakti moment, its gigawatts of solar and wind, its high performance urban development, its inclusive, low-carbon growth.', 'from-megawatts-to-gigawatts-indias-swach-shakti', 'Feb 21, 2015'),
#  ('1754', 'Business', 'Imagine Being Able To See The Doctor And Get Medicine At Work', 'None', 'At some companies an on-site clinic is already a reality.', 'doctor-at-work', 'Feb 25, 2015'),
#  ('1754', 'World News', 'A Growing Rift Between Washington and the Gulf States on Yemen', 'None', "Activity intensified over the past week at the United Nations with respect to the deteriorating situation in Yemen -- amid further evidence of a rift over the country's future between Washington and its traditional Gulf allies.", 'a-growing-rift-between-wa', 'Mar 01, 2015'),
#  ('1754', 'Business', 'The Hottest Cars at the Geneva Auto Show', 'None', 'You can count on the semi-annual Geneva auto show to bring out the most outrageous pieces of automotive design.', 'the-hottest-cars-at-the-g', 'Mar 05, 2015'),
#  ('1754', 'Business', 'One Hack That Turns a Loyal Customer Into a Lifelong Loyal Customer', 'None', 'Loyal customers are great.', 'one-hack-that-turns-a-loy', 'Mar 17, 2015'),
#  ('1754', 'Business', "What's Your R.O.T.? The More You Know, The More You Make", 'None', 'The other day I was tired.', 'whats-your-rot-the-more-y', 'Mar 17, 2015'),
#  ('1754', 'Business', 'Top 80 US Real Estate Crowdfunding Sites Open New Doors in 2015', 'None', 'The evolution of crowdfunding as a new investment vehicle in the US real estate industry has been remarkable in the past few years.', 'top-80-us-real-estate-cro', 'Mar 18, 2015'),
#  ('1754', 'Business', 'Women in Business Q&A', 'None', 'Naama Bloom is the Founder and CEO of HelloFlo, an everyday health and wellness resource for women and girls with sponsorships in place with Tampax, Always, LUNA Bar, and others.', 'women-in-business-qa-naam', 'Apr 05, 2015'),
#  ('1754', 'World News', 'The Kenya Massacre', 'None', 'What we need instead is rule of law in which everyone has a voice and a stake.', 'the-kenya-massacre-why-we', 'Apr 06, 2015'),
#  ('1754', 'Business', '10 Ways Freelance Life Is Different Than A Day Job', 'None', "Wouldn't it be grand if you could trade in the tedious predictability of the 9-to-5 grind for 100 percent control of your efforts and the resulting profits, plus the authority to give yourself as much vacation time as you need.", '10-ways-freelance-life-is-different-than-a-day-job', 'Apr 07, 2015'),
#  ('1754', 'World News', 'The Impact of Energy on China/Myanmar Relations', 'None', "The acquisition of energy has become a dominant influence in China's foreign policy orientation generally, and has been a driving force in its relationship with Myanmar in recent years.", 'the-impact-of-energy-of-c', 'Apr 14, 2015'),
#  ('1754', 'Business', "Executive Onboarding From a Subordinate's Perspective", 'None', "Everything communicates -- everything a new leader says and does and doesn't say and doesn't do.", 'executive-onboarding-from', 'Apr 29, 2015'),
#  ('1754', 'Business', 'What Stephen Curry Can Teach Entrepreneurs', 'None', 'Stephen Curry, like Google and Harvard, provide great examples on the significance of a wow-factor for budding entrepreneurs.', 'stephen-curry-provides-a-', 'Apr 29, 2015'),
#  ('1754', 'World News', 'Yarmouk Camp, Anybody still there?', 'None', 'Sami was one of the pioneers of the revolution in a time when the revolution meant hope.', 'yarmouk-camp-anybody-stil', 'Apr 29, 2015'),
#  ('1754', 'Politics', 'How Racism Is Destroying the Middle Class', 'None', "While the Tea Party, and Republicans, have denied that their war on the poor isn't racially biased, they occasionally slip up.", 'how-racism-is-destroying-', 'May 04, 2015'),
#  ('1754', 'Business', 'The Rise and Fall of Krugmania in the UK', 'None', 'It is already conventional to name the former party leaders Ed Miliband, Nick Clegg and Nigel Farage as the biggest losers of the British general election.', 'the-rise-and-fall-of-krugmania-in-the-uk', 'May 11, 2015'),
#  ('1754', 'Business', '10 Common Mistakes Managers Make That Hurt Their Business', 'None', "Fortunately (and unfortunately) many people that start and run a business often don't know the problems and difficulties they are likely to face.", '10-common-mistakes-managers-make-that-hurt-their-business', 'Jun 13, 2015'),
#  ('1754', 'Business', 'The Job Market', 'None', "There's a common belief that people who don't have jobs somehow just aren't trying hard enough, and this belief is therefore based on the idea that there are enough jobs for everyone.", 'the-job-market-a-game-of-', 'Jun 15, 2015'),
#  ('1754', 'Business', '8 Recruitment Myths Preventing You From Finding the Best', 'None', 'Employees are just as important to a business as the products and services being sold.', '8-recruitment-myths-preve', 'Jun 16, 2015'),
#  ('1754', 'Business', 'Living Local', 'None', 'Look to any local high street at the moment and you will see an economy on the rise.', 'living-localthe-rise-of-l', 'Jun 30, 2015'),
#  ('1754', 'World News', 'The U.S. and China Should Not Risk War Over a "Damn Fool Thing" in the South China Sea', 'None', 'Some territorial claims are easy.', 'the-us-and-china-should-n', 'Jul 04, 2015'),
#  ('1754', 'World News', 'Serbian Prime Minister Attacked At Srebrenica Commemoration', 'None', 'SREBRENICA, Bosnia-Herzegovina (AP) — Anger boiled over Saturday at a massive commemoration of the slaughter of Bosnia Muslims.', 'serbian-prime-minister-attacked', 'Jul 11, 2015'),
#  ('1754', 'World News', 'Greek Financial Crisis Hits Poorest And Hungriest The Hardest', 'None', 'ATHENS — Behind the lace curtains of a soup kitchen run by a parish in the humble Athens neighborhood of Kerameikos, the.', 'Unknown', 'Jul 11, 2015'),
#  ('1754', 'World News', 'Euro Zone Agrees To Move Forward With Bailout Loan For Greece', 'None', 'By Paul Taylor and Renee Maltezou BRUSSELS.', 'euro-zone-greece-bailout', 'Jul 13, 2015'),
#  ('1754', 'Politics', 'Journalists Want Transparency, But Not Right Away', 'None', 'Reporters clash with open government advocates over the merits of a new FOIA policy.', 'journalists-foia-policy', 'Jul 14, 2015'),
#  ('1754', 'Politics', "Martin O'Malley Breaks Into Song At Iowa Campaign Event", 'None', 'The former Maryland governor serenaded supporters with a guitar performance.', 'martin-omalley-song', 'Jul 26, 2015'),
#  ('1754', 'World News', "Syria's Assad Gives First Public Address In A Year", 'None', "BEIRUT (AP) — In his first public address in a year, embattled Syrian President Bashar Assad vowed Sunday to win his country's.", 'syria-assad-speech', 'Jul 26, 2015'),
#  ('1754', 'Politics', "Are Ted Cruz's Super PACs Keeping Their Promise To Support Him?", 'None', 'One pro-Cruz super PAC donated to another Republican presidential candidate.', 'ted-cruzs-super-pacs-have-lots-of-money-but-who-do-they-support', 'Jul 31, 2015'),
#  ('1754', 'Politics', "Hillary Clinton's Shifting Rhetoric On Coal Is A Departure From Her Coal Miner Roots", 'None', 'She walks a fine line between appeasing environmentalists and the coal industry.', 'hillary-clinton-coal', 'Aug 09, 2015'),
#  ('1754', 'World News', '70 Years After the War', 'None', 'Who exactly was Captain Zacharias, beyond being fluent in Japanese and giving himself the title of official spokesman of the U.', '70-years-after-the-war-th', 'Aug 15, 2015'),
#  ('1754', 'Politics', 'Protesters Confront John McCain During Visit To Navajo Capital', 'None', 'A Navajo teen now has what might be the most kick-ass profile picture on Facebook.', 'john-mccain-navajo-nation', 'Aug 17, 2015'),
#  ('1754', 'Politics', "Scott Walker And The Trouble With Obamacare 'Replacement' Plans", 'None', 'Repeal is one thing.', 'scott-walker-obamacare-replacement', 'Aug 18, 2015'),
#  ('1754', 'Politics', 'Joe Biden Meets With Elizabeth Warren Ahead Of Possible Presidential Campaign', 'None', 'Biden is reportedly reaching out to potential people who could support his White House bid.', 'joe-biden-elizabeth-warren', 'Aug 22, 2015'),
#  ('1754', 'World News', 'ISIS Destroys Part Of Another Ancient Temple In Palmyra, Monitor Says', 'None', 'The Temple of Bel has reportedly been severely damaged.', 'isis-palmyra-temple-destroyed-bel', 'Aug 30, 2015'),
#  ('1754', 'Politics', 'Three Rich Treasury Secretaries Laugh It Up Over Income Inequality', 'None', 'LOL.', 'geithner-rubin-paulson-income-inequality', 'Sep 04, 2015'),
#  ('1754', 'World News', "Experts Reject Mexican Government's Account Of Missing Students", 'None', 'The 43 students were abducted in the city of Iguala last September.', 'mexico-missing-students-report-rejected', 'Sep 06, 2015'),
#  ('1754', 'Politics', 'Shooting Reported At Union Station Near Capitol Hill', 'None', 'A security guard shot a man in Union Station in Washington, D.', 'shooting-union-station', 'Sep 11, 2015'),
#  ('1754', 'World News', "Egypt's Government Resigns Amid Corruption Probe", 'None', "CAIRO (AP) — Egypt's government resigned Saturday in the face of intense criticism from state-friendly media that reflects.", 'egypt-government-resigns', 'Sep 12, 2015'),
#  ('1754', 'Business', '9 Books For People Who Need Job Advice But Hate Advice Books', 'None', 'Enjoy.', '9-book-to-get-you-through-your-first-job', 'Sep 22, 2015'),
#  ('1754', 'Business', 'Public Markets Are Great Equalizers In An Age Of Inequality', 'None', 'Markets are some of the few remaining places where people of different economic classes still interact.', 'public-markets-inequality', 'Sep 26, 2015'),
#  ('1754', 'World News', 'France Fires First Airstrikes On Islamic State In Syria', 'None', 'PARIS (AP) — Six French jet fighters targeted and destroyed an Islamic State training camp in eastern Syria, President Francois.', 'france-fires-first-airstrikes-on-islamic-state-in-syria', 'Sep 27, 2015'),
#  ('1754', 'Politics', 'Jeb Bush Just Gave A Middle Finger To The Entire Native American Community', 'None', "Bush says the name of Dan Snyder's team isn't offensive to him.", 'jeb-bush-native-americans', 'Sep 30, 2015'),
#  ('1754', 'Politics', "Justice Breyer Couldn't Save Richard Glossip, But He Won The Day Anyway", 'None', "Oklahoma's disastrous lethal-injection protocol shows he was right about the death penalty all along.", 'stephen-breyer-richard-glossip-death-penalty', 'Oct 03, 2015'),
#  ('1754', 'Politics', 'Watch Robert Kennedy Push Gun Control In Same Town As Recent Mass Shooting', 'None', 'Two weeks before he was assassinated, he addressed gun violence on the campaign trail.', 'robert-kennedy-gun-control-roseburg', 'Oct 05, 2015'),
#  ('1754', 'Politics', 'Ten Commandments Monument Removed From Oklahoma Capitol Grounds', 'None', 'Workers removing the monument were protected by a heavy security presence.', 'oklahoma-ten-commandments', 'Oct 06, 2015'),
#  ('1754', 'Politics', "Homeland Security Secretary Says Border Wall And Fearmongering Are 'Not The Answer' On Immigration", 'None', "Deportation numbers are down, but that doesn't mean immigration enforcement is lying down on the job, he says.", 'jeh-johnson-immigration-border-wall', 'Oct 07, 2015'),
#  ('1754', 'World News', 'ISIS Leader Survives Attack By Iraqi Air Force', 'None', 'Eight other senior figures in ISIS were reported killed.', 'isis-leaders-convoy-hit-by-iraqi-air-force', 'Oct 11, 2015'),
#  ('1754', 'Politics', "Democrats And Independents Are Starting To Like John Boehner Now That He's Leaving", 'None', 'Republicans, not so much.', 'john-boehner-democrats-polls', 'Oct 16, 2015'),
#  ('1754', 'Business', "4-Year-Old Obsessed With CVS Just Got A Birthday Party She'll Never Forget", 'None', 'This is pretty darn cute.', 'cvs-birthday-party-iris-gill', 'Oct 20, 2015'),
#  ('1754', 'World News', 'Death Toll In Romania Fire Rises To 41, Ex-Mayor Arrested', 'None', 'BUCHAREST, Nov 7 (Reuters) - Nine people died on Saturday from injuries sustained in a fire at a nightclub in Romania eight.', 'romania-fire-kills-41-former-mayor-arrested', 'Nov 07, 2015'),
#  ('1754', 'Politics', "Rubio's Mysterious Credit Card Data Revealed", 'None', 'WASHINGTON, Nov 7 (Reuters) - Presidential candidate Marco Rubio put more than $7,000 in personal expenses on a Republican.', 'marco-rubio-credit-card-data-revealed', 'Nov 08, 2015'),
#  ('1754', 'World News', 'Deadly Paris Attacks Come Amid Rising Religious Tension In France', 'None', 'As violent incidents increase, so do claims of anti-Muslim laws and views in the nation.', 'paris-attacks-religion', 'Nov 14, 2015'),
#  ('1754', 'Politics', 'Black Americans Twice As Likely To Report Force In Last Police Encounter', 'None', 'The feds will now track how police departments handle citizen complaints.', 'use-of-force-statistics-doj', 'Nov 16, 2015'),
#  ('1754', 'World News', 'Man Arrested On Flight After Threatening To Open Plane Door', 'None', 'A Serbian handball team helped detain him.', 'lufthansa-plane-arrest-door', 'Dec 06, 2015'),
#  ('1754', 'Business', '9 Idiotic Office Rules That Drive Everyone Insane', 'None', "Companies need to have rules--that's a given--but they don't have to be shortsighted and lazy attempts at creating order.", '9-idiotic-office-rules-th', 'Dec 12, 2015'),
#  ('1754', 'World News', 'As More Borders Close, Families Rush For Refuge', 'None', 'There is now an urgency that has filled the boats from Turkey with more women and children.', 'susan-sarandon-mother-children', 'Dec 25, 2015'),
#  ('1754', 'World News', 'Belgian Police Investigate Alleged Orgy During Terror Lockdown', 'None', 'While authorities searched for suspected Paris attackers, two police officers and eight soldiers allegedly had sex together.', 'belgian-solider-orgy-terror', 'Dec 30, 2015')]
